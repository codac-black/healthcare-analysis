# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('/healthcare_dataset.csv')

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
df.name = df.name.str.strip().str.capitalize()

# %%
df.head()
# Out:
#             name  age  gender blood_type medical_condition date_of_admission  \
# 0  Bobby jackson   30    Male         B-            Cancer        2024-01-31
# 1   Leslie terry   62    Male         A+           Obesity        2019-08-20
# 2    Danny smith   76  Female         A-           Obesity        2022-09-22
# 3   Andrew watts   28  Female         O+          Diabetes        2020-11-18
# 4  Adrienne bell   43  Female        AB+            Cancer        2022-09-19
#
#              doctor                    hospital insurance_provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    billing_amount  room_number admission_type discharge_date   medication  \
# ...

# %%
df.describe(include='object')
# Out:
#                     name gender blood_type medical_condition  \
# count              55500  55500      55500             55500
# unique             40235      2          8                 6
# top     Michael williams   Male         A-         Arthritis
# freq                  24  27774       6969              9308
#
#        date_of_admission         doctor   hospital insurance_provider  \
# count              55500          55500      55500              55500
# unique              1827          40341      39876                  5
# top           2024-03-16  Michael Smith  LLC Smith              Cigna
# freq                  50             27         44              11249
#
#        admission_type discharge_date medication test_results
# count           55500          55500      55500        55500
# unique              3           1856          5            3
# top          Elective     2020-03-15    Lipitor     Abnormal
# freq            18655             53      11140        18627

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                55500 non-null  object
#  1   age                 55500 non-null  int64
#  2   gender              55500 non-null  object
#  3   blood_type          55500 non-null  object
#  4   medical_condition   55500 non-null  object
#  5   date_of_admission   55500 non-null  object
#  6   doctor              55500 non-null  object
#  7   hospital            55500 non-null  object
#  8   insurance_provider  55500 non-null  object
#  9   billing_amount      55500 non-null  float64
#  10  room_number         55500 non-null  int64
#  11  admission_type      55500 non-null  object
#  12  discharge_date      55500 non-null  object
#  13  medication          55500 non-null  object
#  14  test_results        55500 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# name                  0
# age                   0
# gender                0
# blood_type            0
# medical_condition     0
# date_of_admission     0
# doctor                0
# hospital              0
# insurance_provider    0
# billing_amount        0
# room_number           0
# admission_type        0
# discharge_date        0
# medication            0
# test_results          0
# dtype: int64

# %%
df.discharge_date = pd.to_datetime(df.discharge_date, errors='coerce')
df.date_of_admission = pd.to_datetime(df.date_of_admission, errors='coerce')

# %%
df.dtypes
# Out:
# name                          object
# age                            int64
# gender                        object
# blood_type                    object
# medical_condition             object
# date_of_admission     datetime64[ns]
# doctor                        object
# hospital                      object
# insurance_provider            object
# billing_amount               float64
# room_number                    int64
# admission_type                object
# discharge_date        datetime64[ns]
# medication                    object
# test_results                  object
# dtype: object

# %%
# removin the negative values in billing_amount
df = df[df.billing_amount >= 0]

# %%
# Distribution of Age
fig_age  = px.histogram(
    df,
    x='age',
    nbins=30,
    title='Age Distribution Of Patients',
    labels={"age": "Age"},
    marginal="box",
    color_discrete_sequence=["green"]
)
fig_age.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Gender Distribution
fig_gender = px.pie(
    df,
    names='gender',
    title='Gender Distribution',
    color_discrete_sequence=px.colors.qualitative.Set2
)

fig_gender.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Billing amount distribution
fig_billing = px.box(
    df,
    y='billing_amount',
    title='Billing Amount Distribution',
    labels={
        'billing_amount': 'Billing Amount'
    },
    color_discrete_sequence=['red']
)
fig_billing.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# most Common medical Conditions
medical_counts = df.medical_condition.value_counts()
fig_medical = px.bar(
    x=medical_counts.index,
    y=medical_counts.values,
    title='Top Medical Conditions',
    labels={
        'x': 'Medical Condition',
        'y': 'Count'
    },
    color_discrete_sequence=['green']

)
fig_medical.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Admission Type Breakdown
fig_admissions = px.pie(
    df,
    names='admission_type',
    title='Admission Type Distribution',
    color_discrete_sequence=px.colors.qualitative.Set2
)

fig_admissions.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Top Hospitals by Patients Counts
def hospital_viz(num_of_hospitals:int):
    hospital_counts = df.hospital.value_counts().nlargest(num_of_hospitals)
    fig_hospital = px.bar(
        x=hospital_counts.index,
        y=hospital_counts.values,
        title=f'Top {num_of_hospitals} Hospitals by Patients Counts',
        labels={
            'x': 'Hospital',
            'y': 'Number of Patients'
        },
        color_discrete_sequence=px.colors.qualitative.Set2
    )

    return fig_hospital.show()

hospital_viz(6)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.insurance_provider.value_counts()
# Out:
# insurance_provider
# Cigna               11225
# Medicare            11132
# UnitedHealthcare    11106
# Blue Cross          11043
# Aetna               10886
# Name: count, dtype: int64

# %%
fig_insurance = px.pie(
    df,
    names='insurance_provider',
    title='Insurance Providers Distribution',
    color_discrete_sequence=px.colors.qualitative.Set3
)

fig_insurance.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
